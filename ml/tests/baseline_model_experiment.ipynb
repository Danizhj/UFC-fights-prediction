# %% [markdown]
# # Baseline Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, cross_val_predict, StratifiedKFold, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, fbeta_score, classification_report
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/processed/train_processed.csv')
X = df.drop('outcome', axis=1)
y = df.outcome

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# %%
model = RandomForestClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.71      0.72       526
#          1.0       0.70      0.72      0.71       508
#
#     accuracy                           0.71      1034
#    macro avg       0.71      0.71      0.71      1034
# weighted avg       0.72      0.71      0.71      1034

# %% [markdown]
# # Hyperparameters Optimization

# %%
def print_all_scores(y_true, y_pred):
    print('Accuracy_score:', accuracy_score(y_true, y_pred))
    print('Precision_score:', precision_score(y_true, y_pred))
    print('Recall_score:', recall_score(y_true, y_pred))
    print('F1_score:', f1_score(y_true, y_pred))
    print('ROC_score:', roc_auc_score(y_true, y_pred))

# %%
import optuna
from optuna.samplers import TPESampler

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 50, 500),
        "max_depth": trial.suggest_int("max_depth", 3, 40),
        "min_samples_split": trial.suggest_int("min_samples_split", 2, 20),
        "min_samples_leaf": trial.suggest_int("min_samples_leaf", 1, 10),
        "max_features": trial.suggest_categorical("max_features", ['sqrt', "log2", None]),
        "bootstrap": trial.suggest_categorical("bootstrap", [True, False])
    }
    
    model = RandomForestClassifier(**params, random_state=123)
    score = cross_val_score(model, X, y, cv=5, scoring='f1').mean()
    return score

# %%
study = optuna.create_study(direction='maximize', sampler=TPESampler(seed=123))
study.optimize(objective, n_trials = 100)
print("Best params ", study.best_params)
print("Best score ", study.best_value)
# Out:
# [I 2025-11-28 17:33:31,648] A new study created in memory with name: no-name-08a94952-cc11-4aae-bdee-5e1792e9fafe
# [I 2025-11-28 17:33:59,379] Trial 0 finished with value: 0.7126225203431117 and parameters: {'n_estimators': 364, 'max_depth': 13, 'min_samples_split': 6, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.7126225203431117.
# [I 2025-11-28 17:34:17,519] Trial 1 finished with value: 0.7111880062620166 and parameters: {'n_estimators': 226, 'max_depth': 16, 'min_samples_split': 15, 'min_samples_leaf': 5, 'max_features': None, 'bootstrap': True}. Best is trial 0 with value: 0.7126225203431117.
# [I 2025-11-28 17:34:26,388] Trial 2 finished with value: 0.7145675420585265 and parameters: {'n_estimators': 289, 'max_depth': 23, 'min_samples_split': 14, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:34:40,217] Trial 3 finished with value: 0.7116461364446772 and parameters: {'n_estimators': 152, 'max_depth': 14, 'min_samples_split': 13, 'min_samples_leaf': 1, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:34:47,631] Trial 4 finished with value: 0.7102036190914188 and parameters: {'n_estimators': 242, 'max_depth': 36, 'min_samples_split': 19, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:35:00,043] Trial 5 finished with value: 0.7130334669535243 and parameters: {'n_estimators': 162, 'max_depth': 21, 'min_samples_split': 20, 'min_samples_leaf': 6, 'max_features': None, 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:35:06,370] Trial 6 finished with value: 0.71211398819281 and parameters: {'n_estimators': 204, 'max_depth': 14, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:35:45,833] Trial 7 finished with value: 0.6381433017701881 and parameters: {'n_estimators': 354, 'max_depth': 35, 'min_samples_split': 3, 'min_samples_leaf': 8, 'max_features': None, 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:35:53,609] Trial 8 finished with value: 0.7145121886039446 and parameters: {'n_estimators': 332, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 6, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:03,870] Trial 9 finished with value: 0.7138425077347035 and parameters: {'n_estimators': 362, 'max_depth': 24, 'min_samples_split': 9, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:09,988] Trial 10 finished with value: 0.7117689334018363 and parameters: {'n_estimators': 493, 'max_depth': 4, 'min_samples_split': 15, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:11,348] Trial 11 finished with value: 0.7087595622577896 and parameters: {'n_estimators': 51, 'max_depth': 30, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:20,449] Trial 12 finished with value: 0.7122306565346697 and parameters: {'n_estimators': 298, 'max_depth': 27, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:32,136] Trial 13 finished with value: 0.7129472544646033 and parameters: {'n_estimators': 459, 'max_depth': 40, 'min_samples_split': 6, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:40,865] Trial 14 finished with value: 0.7106172204496098 and parameters: {'n_estimators': 403, 'max_depth': 31, 'min_samples_split': 17, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': True}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:36:52,238] Trial 15 finished with value: 0.7110990119131999 and parameters: {'n_estimators': 296, 'max_depth': 21, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17:37:01,367] Trial 16 finished with value: 0.7124843136155473 and parameters: {'n_estimators': 298, 'max_depth': 25, 'min_samples_split': 11, 'min_samples_leaf': 8, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 2 with value: 0.7145675420585265.
# [I 2025-11-28 17
max_depth': 9, 'min_samples_split': 19, 'min_samples_leaf': 5, 'max_features': 'log2', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:13,685] Trial 77 finished with value: 0.7154171288788036 and parameters: {'n_estimators': 289, 'max_depth': 11, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:17,972] Trial 78 finished with value: 0.7124917778600663 and parameters: {'n_estimators': 287, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:26,598] Trial 79 finished with value: 0.7117401610480434 and parameters: {'n_estimators': 264, 'max_depth': 11, 'min_samples_split': 7, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:34,917] Trial 80 finished with value: 0.7098880701883791 and parameters: {'n_estimators': 234, 'max_depth': 15, 'min_samples_split': 10, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:44,057] Trial 81 finished with value: 0.7125610136271934 and parameters: {'n_estimators': 303, 'max_depth': 10, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:45:50,649] Trial 82 finished with value: 0.7121673332761012 and parameters: {'n_estimators': 316, 'max_depth': 7, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:23,631] Trial 83 finished with value: 0.6424854715213033 and parameters: {'n_estimators': 273, 'max_depth': 12, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': None, 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:31,754] Trial 84 finished with value: 0.7117387370987961 and parameters: {'n_estimators': 295, 'max_depth': 9, 'min_samples_split': 8, 'min_samples_leaf': 2, 'max_features': 'log2', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:38,332] Trial 85 finished with value: 0.7128455653644138 and parameters: {'n_estimators': 345, 'max_depth': 6, 'min_samples_split': 17, 'min_samples_leaf': 4, 'max_features': 'log2', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:46,408] Trial 86 finished with value: 0.7150662054415413 and parameters: {'n_estimators': 331, 'max_depth': 8, 'min_samples_split': 2, 'min_samples_leaf': 5, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:49,378] Trial 87 finished with value: 0.7131251163680681 and parameters: {'n_estimators': 252, 'max_depth': 4, 'min_samples_split': 13, 'min_samples_leaf': 7, 'max_features': 'log2', 'bootstrap': True}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:46:59,184] Trial 88 finished with value: 0.7162299194118305 and parameters: {'n_estimators': 362, 'max_depth': 10, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:47:10,458] Trial 89 finished with value: 0.7134489006671542 and parameters: {'n_estimators': 388, 'max_depth': 23, 'min_samples_split': 18, 'min_samples_leaf': 10, 'max_features': 'log2', 'bootstrap': False}. Best is trial 73 with value: 0.7162832146957229.
# [I 2025-11-28 17:47:19,628] Trial 90 finished with value: 0.7170326401337671 and parameters: {'n_estimators': 363, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 90 with value: 0.7170326401337671.
# [I 2025-11-28 17:47:28,786] Trial 91 finished with value: 0.7172762570598474 and parameters: {'n_estimators': 364, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:47:38,956] Trial 92 finished with value: 0.716355523945194 and parameters: {'n_estimators': 398, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:47:50,439] Trial 93 finished with value: 0.7128781509012029 and parameters: {'n_estimators': 422, 'max_depth': 12, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:00,061] Trial 94 finished with value: 0.7166280434060284 and parameters: {'n_estimators': 383, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:10,054] Trial 95 finished with value: 0.7168831310686125 and parameters: {'n_estimators': 388, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:21,176] Trial 96 finished with value: 0.7152369571674703 and parameters: {'n_estimators': 401, 'max_depth': 13, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:31,164] Trial 97 finished with value: 0.7155439318784065 and parameters: {'n_estimators': 388, 'max_depth': 10, 'min_samples_split': 20, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:43,322] Trial 98 finished with value: 0.713208751567397 and parameters: {'n_estimators': 451, 'max_depth': 11, 'min_samples_split': 20, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# [I 2025-11-28 17:48:53,819] Trial 99 finished with value: 0.7146341898338038 and parameters: {'n_estimators': 412, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 9, 'max_features': 'sqrt', 'bootstrap': False}. Best is trial 91 with value: 0.7172762570598474.
# Best params  {'n_estimators': 364, 'max_depth': 10, 'min_samples_split': 19, 'min_samples_leaf': 10, 'max_features': 'sqrt', 'bootstrap': False}
# Best score  0.7172762570598474

# %%
best_params = {
    "n_estimators": 276,
    "max_depth": 13,
    "min_samples_split": 12,
    "min_samples_leaf": 9,
    "max_features": "sqrt",
    "bootstrap": True
}

# %%
model = RandomForestClassifier(**best_params, random_state=123)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print_all_scores(y_test, y_pred)
# Out:
# Accuracy_score: 0.706963249516441
# Precision_score: 0.697495183044316
# Recall_score: 0.7125984251968503
# F1_score: 0.7049659201557936
# ROC_score: 0.7070596688721895
